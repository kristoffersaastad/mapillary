# %%
import sklearn
import pandas as pd
import numpy as np
import seaborn as sns
from imblearn.combine import SMOTETomek
from matplotlib import pyplot as plt
from IPython.display import display
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-317-8a9aeaff1d3e> in <module>
#       3 import numpy as np
#       4 import seaborn as sns
# ----> 5 from imblearn.combine import SMOTETomek
#       6 from matplotlib import pyplot as plt
#       7 from IPython.display import display
#
# /mnt/c/Users/krist/Documents/mapillary/venv/lib/python3.6/site-packages/imblearn/__init__.py in <module>
#      32     Module which allowing to create pipeline with scikit-learn estimators.
#      33 """
# ---> 34 from . import combine
#      35 from . import ensemble
#      36 from . import exceptions
#
# /mnt/c/Users/krist/Documents/mapillary/venv/lib/python3.6/site-packages/imblearn/combine/__init__.py in <module>
#       3 """
#       4
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       7
#
# /mnt/c/Users/krist/Documents/mapillary/venv/lib/python3.6/site-packages/imblearn/combine/_smote_enn.py in <module>
#       8 from sklearn.utils import check_X_y
#       9
# ---> 10 from ..base import BaseSampler
#      11 from ..over_sampling import SMOTE
#      12 from ..over_sampling.base import BaseOverSampler
#
# /mnt/c/Users/krist/Documents/mapillary/venv/lib/python3.6/site-packages/imblearn/base.py in <module>
#      14 from sklearn.utils.multiclass import check_classification_targets
#      15
# ---> 16 from .utils import check_sampling_strategy, check_target_type
#      17
#      18
#
# /mnt/c/Users/krist/Documents/mapillary/venv/lib/python3.6/site-packages/imblearn/utils/__init__.py in <module>
#       5 from ._docstring import Substitution
#       6
# ----> 7 from ._validation import check_neighbors_object
#       8 from ._validation import check_target_type
#       9 from ._validation import check_sampling_strategy
#
# /mnt/c/Users/krist/Documents/mapillary/venv/lib/python3.6/site-packages/imblearn/utils/_validation.py in <module>
#      11
#      12 from sklearn.base import clone
# ---> 13 from sklearn.neighbors._base import KNeighborsMixin
#      14 from sklearn.neighbors import NearestNeighbors
#      15 from sklearn.utils.multiclass import type_of_target
#
# ModuleNotFoundError: No module named 'sklearn.neighbors._base'

# %%
def match_data_to_labels(train, labels):
    columns_names=list(train.columns) + list(labels.columns)
    df = pd.DataFrame(np.zeros([labels.shape[0], train.shape[1]+1]), columns=columns_names, index=labels.index)
    for _id, seq in df.iterrows():
        for item in columns_names[:-1]:
            seq[item] = train.at[_id, item]
        seq["label"] = labels.at[_id,"label"]
    return df

# %%
raw_data = pd.read_csv("training_data/features.csv").drop_duplicates(subset=["id"],keep="first").set_index("id")
labels = pd.read_csv("sequence_labels.csv").drop_duplicates(subset=["id"],keep="first").set_index("id")
data = match_data_to_labels(raw_data, labels)
features = data.columns.values[:-1]
data.head()
# Out:
#                         avg_speed  min_speed  max_speed  max_accel  \
# id
# 6lmxhlsdu2820pp9ewk41z  16.092218   0.232964  25.961550  10.652202
# g234mtreigui4a64i4xea9   6.322339   0.141193  12.872192   3.198201
# hwt93drmgmyk3pnt7hib08   1.275309   0.620147   2.196088   1.129826
# 9gmnn1cdfv7vbptl9p83u2   1.210824   0.079203   2.395365   1.275051
# 18ejk5cjxixj051qiupxyb   1.313297   0.637032   2.017232   1.256552
#
#                         max_deaccel  med_speed  med_accel  sd_speed  sd_accel  \
# id
# 6lmxhlsdu2820pp9ewk41z   -13.501058  12.864293  12.076630  5.964283  2.795336
# g234mtreigui4a64i4xea9    -6.585177   6.365499   4.891689  2.824493  1.406421
# hwt93drmgmyk3pnt7hib08    -7.976933   0.787971   4.553379  0.274747  0.971887
# 9gmnn1cdfv7vbptl9p83u2    -4.657094   1.158081   2.966073  0.336322  0.656864
# 18ejk5cjxixj051qiupxyb    -2.369025   0.690100   1.812788  0.291555  0.574907
#
#                         percent_ped_speed  percent_bic_speed  \
# id
# 6lmxhlsdu2820pp9ewk41z           0.697674           6.279070
# g234mtreigui4a64i4xea9           0.735294          20.588235
# hwt93drmgmyk3pnt7hib08          67.193676           0.000000
# 9gmnn1cdfv7vbptl9p83u2          60.103627           0.000000
# 18ejk5cjxixj051qiupxyb          57.831325           0.000000
#
#                         percent_car_speed  num_stops  sinuosity     distance  \
# id
# 6lmxhlsdu2820pp9ewk41z          86.511628        0.0   1.037741  7917.451715
# g234mtreigui4a64i4xea9          36.764706        2.0   1.007190  1132.324604
# hwt93drmgmyk3pnt7hib08           0.000000        0.0   2.232828   366.273853
# 9gmnn1cdfv7vbptl9p83u2           0.000000        4.0   1.304693   562.095759
# 18ejk5cjxixj051qiupxyb           0.000000        0.0   1.040797   126.595226
#
#                         duration  label
# id
# 6lmxhlsdu2820pp9ewk41z   492.005    2.0
# g234mtreigui4a64i4xea9   179.099    2.0
# hwt93drmgmyk3pnt7hib08   287.204    0.0
# 9gmnn1cdfv7vbptl9p83u2   464.226    0.0
# 18ejk5cjxixj051qiupxyb    96.395    0.0

# %%
data.label.value_counts().plot(kind='bar', title='Count (target)')
data.label.value_counts()
# Out:
# 0.0    244
# 1.0    116
# 2.0     86
# Name: label, dtype: int64

# %%
cor = data[features].corr(method="pearson")
display(pd.DataFrame(cor))
fig, ax =plt.subplots(figsize=(8, 6))
plt.title("Correlation Plot")
sns.heatmap(cor, mask=np.zeros_like(cor, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True), ax=ax)
plt.show()
# Out:
#                    avg_speed  min_speed  max_speed  max_accel  max_deaccel  \
# avg_speed           1.000000   0.829287   0.507611   0.179062    -0.474213
# min_speed           0.829287   1.000000   0.311747   0.011590    -0.274082
# max_speed           0.507611   0.311747   1.000000   0.916447    -0.957129
# max_accel           0.179062   0.011590   0.916447   1.000000    -0.866746
# max_deaccel        -0.474213  -0.274082  -0.957129  -0.866746     1.000000
# med_speed           0.380769   0.146449   0.985576   0.952050    -0.947651
# med_accel           0.342483   0.151754   0.970224   0.964098    -0.968069
# sd_speed            0.721296   0.398088   0.845754   0.631168    -0.876997
# sd_accel            0.598470   0.355261   0.909600   0.787206    -0.954252
# percent_ped_speed  -0.323633  -0.143621  -0.231340  -0.148866     0.175615
# percent_bic_speed  -0.027827  -0.093592  -0.010016   0.001155     0.036146
# percent_car_speed   0.722478   0.458008   0.392651   0.190270    -0.311218
# num_stops           0.043702  -0.042134   0.671085   0.755664    -0.711816
# sinuosity           0.005549  -0.012324   0.006285   0.009260     0.004647
# distance            0.275305  -0.011823   0.358507   0.351196    -0.232461
# duration           -0.067219  -0.124819   0.019327   0.062832     0.019034
#
#                    med_speed  med_accel  sd_speed  sd_accel  \
# avg_speed           0.380769   0.342483  0.721296  0.598470
# min_speed           0.146449   0.151754  0.398088  0.355261
# max_speed           0.985576   0.970224  0.845754  0.909600
# max_accel           0.952050   0.964098  0.631168  0.787206
# max_deaccel        -0.947651  -0.968069 -0.876997 -0.954252
# med_speed           1.000000   0.983073  0.809612  0.883710
# med_accel           0.983073   1.000000  0.784173  0.903733
# sd_speed            0.809612   0.784173  1.000000  0.930294
# sd_accel            0.883710   0.903733  0.930294  1.000000
# percent_ped_speed  -0.215268  -0.168325 -0.272098 -0.209589
# percent_bic_speed   0.006242  -0.018664 -0.015527 -0.039816
# percent_car_speed   0.327213   0.261334  0.515030  0.400671
# num_stops           0.706172   0.758801  0.491075  0.646363
# sinuosity           0.008738   0.002180  0.014596  0.012166
# distance            0.375348   0.300287  0.315379  0.270681
# duration            0.042353   0.021446 -0.018413 -0.021857
#
#                    percent_ped_speed  percent_bic_speed  percent_car_speed  \
# avg_speed                  -0.323633          -0.027827           0.722478
# min_speed                  -0.143621          -0.093592           0.458008
# max_speed                  -0.231340          -0.010016           0.392651
# max_accel                  -0.148866           0.001155           0.190270
# max_deaccel                 0.175615           0.036146          -0.311218
# med_speed                  -0.215268           0.006242           0.327213
# med_accel                  -0.168325          -0.018664           0.261334
# sd_speed                   -0.272098          -0.015527           0.515030
# sd_accel                   -0.209589          -0.039816           0.400671
# percent_ped_speed           1.000000          -0.555007          -0.430149
# percent_bic_speed          -0.555007           1.000000          -0.076057
# percent_car_speed          -0.430149          -0.076057           1.000000
# num_stops                  -0.157998           0.069504           0.009917
# sinuosity                  -0.059652           0.044471           0.032599
# distance                   -0.373867           0.103225           0.618266
# duration                   -0.017425           0.068914           0.035108
#
#                    num_stops  sinuosity  distance  duration
# avg_speed           0.043702   0.005549  0.275305 -0.067219
# min_speed          -0.042134  -0.012324 -0.011823 -0.124819
# max_speed           0.671085   0.006285  0.358507  0.019327
# max_accel           0.755664   0.009260  0.351196  0.062832
# max_deaccel        -0.711816   0.004647 -0.232461  0.019034
# med_speed           0.706172   0.008738  0.375348  0.042353
# med_accel           0.758801   0.002180  0.300287  0.021446
# sd_speed            0.491075   0.014596  0.315379 -0.018413
# sd_accel            0.646363   0.012166  0.270681 -0.021857
# percent_ped_speed  -0.157998  -0.059652 -0.373867 -0.017425
# percent_bic_speed   0.069504   0.044471  0.103225  0.068914
# percent_car_speed   0.009917   0.032599  0.618266  0.035108
# num_stops           1.000000  -0.007920  0.192586  0.071706
# sinuosity          -0.007920   1.000000  0.101286  0.092420
# distance            0.192586   0.101286  1.000000  0.435083
# duration            0.071706   0.092420  0.435083  1.000000
